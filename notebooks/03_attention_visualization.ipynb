# %% [markdown]
# # 03. Interpretability via Temporal Graph Attention Weights
# ### Spatio-Temporal Intrusion Detection System (TGNN-IDS)
#
# Demonstrating Contribution C1: Extracting beta_k(t) attention weights to identify
# which past time windows contributed most to high-confidence anomaly detections.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath("..""))
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from models.tgnn_ids import TGNNIDS
from evaluation.visualizations import plot_temporal_attention_weights
print("Loaded attention inspector.")
